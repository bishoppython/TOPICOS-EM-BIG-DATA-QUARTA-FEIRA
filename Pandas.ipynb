# %% [markdown]
# <a href="https://colab.research.google.com/github/bishoppython/TOPICOS-EM-BIG-DATA-QUARTA-FEIRA/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# #### Series

# %%
dados = pd.Series([10, 20, 30, 40, 50])
dados

# %% [markdown]
# #### DataFrame

# %%
dados = {
    "Nome":["Alice", "Bob Nelson", "Carlos"],
    "Idade":[25, 30, 35],
    "Cidade":["São Paulo", "Recife", "Belo Horizonte"],
    "Curso":["Ciência da Computação", "Medicina", "Direito"],
    "Periodo":[1, 5, 8]
}
df = pd.DataFrame(dados)
df
# Out:
#          Nome  Idade          Cidade                  Curso  Periodo
# 0       Alice     25       São Paulo  Ciência da Computação        1
# 1  Bob Nelson     30          Recife               Medicina        5
# 2      Carlos     35  Belo Horizonte                Direito        8

# %% [markdown]
# #### Explorando Dados

# %%
df.head() #Primeiras Linhas
# Out:
#          Nome  Idade          Cidade                  Curso  Periodo
# 0       Alice     25       São Paulo  Ciência da Computação        1
# 1  Bob Nelson     30          Recife               Medicina        5
# 2      Carlos     35  Belo Horizonte                Direito        8

# %%
df.tail() #Ultimas Linhas
# Out:
#          Nome  Idade          Cidade                  Curso  Periodo
# 0       Alice     25       São Paulo  Ciência da Computação        1
# 1  Bob Nelson     30          Recife               Medicina        5
# 2      Carlos     35  Belo Horizonte                Direito        8

# %%
df.info() #Informações do DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Nome     3 non-null      object
#  1   Idade    3 non-null      int64
#  2   Cidade   3 non-null      object
#  3   Curso    3 non-null      object
#  4   Periodo  3 non-null      int64
# dtypes: int64(2), object(3)
# memory usage: 252.0+ bytes

# %%
df.describe() #Estatísticas do DataFrame
# Out:
#        Idade   Periodo
# count    3.0  3.000000
# mean    30.0  4.666667
# std      5.0  3.511885
# min     25.0  1.000000
# 25%     27.5  3.000000
# 50%     30.0  5.000000
# 75%     32.5  6.500000
# max     35.0  8.000000

# %%
df.columns # Nomes das Colunas
# Out:
# Index(['Nome', 'Idade', 'Cidade', 'Curso', 'Periodo'], dtype='object')

# %%
df.shape # Número de linhas e colunas
# Out:
# (3, 5)

# %% [markdown]
# #### Atividade

# %%
import pandas as pd

sheet_id = "1jpJSIM6F6foWuWsOsyJirznz8F4xWMt6-KDYFHeHrhc"  # substitua pelo ID da sua planilha
gid = "0"  # substitua pelo gid da aba desejada, se necessário

url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/export?format=csv&gid={gid}"
df = pd.read_csv(url)

print(df.head())
# Out:
#    ID          CPF                             NOME                DISCIPLINA  \
# 0   1  20250000001             ARTHUR LUIZ DA SILVA       TÓPICOS DE BIG DATA
# 1   2  20250000002     BRENO ANTONY OLIVEIRA PONTES  ENGENHARIA DE SOFTWARE I
# 2   3  20250000003              BRUNO ARAÚJO BARROS       TÓPICOS DE BIG DATA
# 3   4  20250000004  CARLOS NATAN RODRIGUES DA SILVA                 CALCULO I
# 4   5  20250000005            Carolina Dias Barreto                CALCULO II
#
#    NOTA_BI_1 NOTA_BI_2 NOTA_BI_3
# 0          8         6         8
# 1          7         6         7
# 2          9         6        13
# 3          6         6      1100
# 4          8         6      1114

# %%
import pandas as pd

df = pd.read_csv("/content/Dados Tópicos de Big Data - Quarta Feira.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         36 non-null     int64
#  1   CPF        36 non-null     int64
#  2   NOME       36 non-null     object
#  3   NOTA_BI_1  36 non-null     int64
#  4   NOTA_BI_2  35 non-null     object
#  5   NOTA_BI_3  36 non-null     object
# dtypes: int64(3), object(3)
# memory usage: 1.8+ KB
